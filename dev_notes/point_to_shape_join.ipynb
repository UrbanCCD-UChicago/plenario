# %%
from sqlalchemy import func, cast, Table, select, text, Column, MetaData
from sqlalchemy import Integer, String
from plenario.database import session, app_engine, Base
from plenario.models import MetaTable, ShapeMetadata

# %%
t = MetaTable.get_by_dataset_name('crimes').point_table

# %%
t
# Out:
# Table('crimes', MetaData(bind=Engine(postgresql://postgres:***@localhost:5432/plenario_test)), Column('id', INTEGER(), table=<crimes>), Column('case_number', VARCHAR(), table=<crimes>), Column('date', TIMESTAMP(), table=<crimes>), Column('block', VARCHAR(), table=<crimes>), Column('iucr', DOUBLE_PRECISION(precision=53), table=<crimes>), Column('primary_type', VARCHAR(), table=<crimes>), Column('description', VARCHAR(), table=<crimes>), Column('location_description', VARCHAR(), table=<crimes>), Column('arrest', BOOLEAN(), table=<crimes>), Column('domestic', BOOLEAN(), table=<crimes>), Column('beat', DOUBLE_PRECISION(precision=53), table=<crimes>), Column('district', DOUBLE_PRECISION(precision=53), table=<crimes>), Column('ward', INTEGER(), table=<crimes>), Column('community_area', INTEGER(), table=<crimes>), Column('fbi_code', DOUBLE_PRECISION(precision=53), table=<crimes>), Column('x_coordinate', INTEGER(), table=<crimes>), Column('y_coordinate', INTEGER(), table=<crimes>), Column('y
# ...

# %%
sel = t.select().alias('crime_stuff')
print sel
# Out:
# SELECT crimes.id, crimes.case_number, crimes.date, crimes.block, crimes.iucr, crimes.primary_type, crimes.description, crimes.location_description, crimes.arrest, crimes.domestic, crimes.beat, crimes.district, crimes.ward, crimes.community_area, crimes.fbi_code, crimes.x_coordinate, crimes.y_coordinate, crimes.year, crimes.updated_on, crimes.latitude, crimes.longitude, crimes.location, crimes.hash, crimes.point_date, ST_AsBinary(crimes.geom) AS geom
# FROM crimes

# %%
shape_table = session.query(ShapeMetadata).get('chicago_neighborhoods').shape_table

join = sel.join(shape_table, sel.c.geom.ST_Within(shape_table.c.geom))

# %%
type(join)
kludge = join.select()
row = app_engine.execute(kludge).fetchall()[0]

# %%
len(row)
# Out:
# 31

# %%
row
# Out:
# (10271156, u'HY459418', datetime.datetime(2015, 10, 12, 0, 0), u'0000X E ADAMS ST', 1150.0, u'DECEPTIVE PRACTICE', u'CREDIT CARD FRAUD', u'SIDEWALK', False, False, 113.0, 1.0, 42, 32, 11.0, 1176689, 1899474, 2015, datetime.datetime(2015, 10, 19, 15, 58, 42), 41.879505465, -87.626683155, u'(41.879505465, -87.626683155)', u'5e5e8094fdb4fd130ec94379cfe963a4', datetime.datetime(2015, 10, 12, 0, 0), <WKBElement at 0x109f48b50; '010100000076eba9931be855c0056a94a293f04440'>, 54, <WKBElement at 0x109f48650; '...'>, u'Loop', u'LOOP', 31485185.0318, 52640.907563)
